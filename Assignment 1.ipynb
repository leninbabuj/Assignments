# %% [markdown]
# # Task 1
#
# ##### 1: Install Jupyter notebook and run the first program and share the screenshot of the output.
#
# ##### 2: Write a program which will find all such numbers which are divisible by 7 but are not a multiple of 5, between 2000 and 3200 (both included). The numbers obtained should be printed in a comma-separated sequence on a single line.

# %%
l = list(range(2000,3201))
for i in l:
    if i%7==0 and i%5!=0:
        print (str(i),end=',')

# %% [markdown]
# ##### 3: Write a Python program to accept the user's first and last name and then getting them printed in the the reverse order with a space between first name and last name.

# %%
First_Name = input("Enter First Name : ")
Last_Name = input("Enter Last Name : ")
print(Last_Name, First_Name)

# %% [markdown]
# ##### 4: Write a Python program to find the volume of a sphere with diameter 12 cm. Formula: V=4/3 * π * r 3
#
# ![Volume.PNG](attachment:Volume.PNG)

# %%
d = 12 # d for Diameter
pi = 3.14159 # pi for π
r = 6 # r for radious 12cm/2 that is 6
V = round(((4/3)*(pi)*(r**3)),2) # V for volume of sphere
print("Volume of sphere", V, "cubic cm")

# %% [markdown]
# # Task 2
#
# ##### 1: Create the below pattern using nested for loop in Python.
# ![Pattern.PNG](attachment:Pattern.PNG)

# %%
for i in range(0,5):
    print("*"*i)
for i in range(5,0,-1):
    print("*"*i)

# %% [markdown]
# ##### 2: Write a Python program to reverse a word after accepting the input from the user.

# %%
word = input('Enter a Word : ')
lst = list(word)
print(lst[::-1])

# %% [markdown]
# ##### 3 : Write a Python Program to print the given string in the format specified in the sample output.
#
#         WE, THE PEOPLE OF INDIA, having solemnly resolved to constitute India into a
#         SOVEREIGN, SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC and to secure to all
#         its citizens
#
# ![Sample%20Output.PNG](attachment:Sample%20Output.PNG)

# %%
print("WE, THE PEOPLE OF INDIA,","\n \t having solemnly resolved to constitute India into a SOVEREIGN, !","\n\t\tSOCIALIST, SECULAR, DEMOCRATIC REPUBLIC","\n \t\t and to secure to all its citizens")
